# %%
import pandas as pd
df_tendencia = pd.read_excel('matricula.xlsx',
                       sheet_name='Hoja04',
                       skiprows=0,
                       skipfooter=0)

print ('Datos leídos en un marco de datos de pandas!')
# Out:
# Datos leídos en un marco de datos de pandas!

# %%
df_tendencia.head(5)
# Out:
#      REGION       2001       2002       2003       2004       2005       2006
# 0  Amazonas  59.957847  59.354099  68.700436  63.249094  61.117406  63.949402  \
# 1    Ancash  51.832932  54.948729   54.89229  63.157986  69.871893  65.974263
# 2  Apurímac  61.142286  58.399844  53.339032  68.811045  67.231891  66.631860
# 3  Arequipa  80.425588  82.699463  74.576988  89.332278  86.075536  81.631867
# 4  Ayacucho  53.573045  48.976799  49.974511  50.725844  59.555397  50.888510
#
#         2007       2008       2009       2010       2011       2012
# 0  53.709937  61.203100  60.972830  61.817111  64.086410  68.889297  \
# 1  71.589496  74.242416  68.823060  72.112824  78.050841  77.733436
# 2  67.815028  70.708028  78.780984  78.609518  78.604583  77.389747
# 3  88.978596  90.419176  87.895861  93.502294  86.709338  90.422880
# 4  64.104548  62.537206  61.884559  62.943788  69.388476  71.504411
#
#         2013       2014       2015
# 0  71.296644  70.935720  74.234666
# ...

# %%
df_tendencia.shape
# Out:
# (26, 16)

# %%
all(isinstance(column, str) for column in df_tendencia.columns)
# Out:
# False

# %%
df_tendencia.columns = list(map(str, df_tendencia.columns))
all(isinstance(column, str) for column in df_tendencia.columns)
# Out:
# True

# %%
df_tendencia.set_index('REGION', inplace=True)
df_tendencia.head()
# Out:
#                2001       2002       2003       2004       2005       2006
# REGION
# Amazonas  59.957847  59.354099  68.700436  63.249094  61.117406  63.949402  \
# Ancash    51.832932  54.948729   54.89229  63.157986  69.871893  65.974263
# Apurímac  61.142286  58.399844  53.339032  68.811045  67.231891  66.631860
# Arequipa  80.425588  82.699463  74.576988  89.332278  86.075536  81.631867
# Ayacucho  53.573045  48.976799  49.974511  50.725844  59.555397  50.888510
#
#                2007       2008       2009       2010       2011       2012
# REGION
# Amazonas  53.709937  61.203100  60.972830  61.817111  64.086410  68.889297  \
# Ancash    71.589496  74.242416  68.823060  72.112824  78.050841  77.733436
# Apurímac  67.815028  70.708028  78.780984  78.609518  78.604583  77.389747
# Arequipa  88.978596  90.419176  87.895861  93.502294  86.709338  90.422880
# Ayacucho  64.104548  62.537206  61.884559  62.943788  69.388476  71.504411
#
#                2013       2014       2015
# ...

# %%
df_tendencia.shape
# Out:
# (26, 15)

# %%
df_tendencia['Promedio'] = (len(df_tendencia.columns)-1)

df_tendencia.head()
# Out:
#                2001       2002       2003       2004       2005       2006
# REGION
# Amazonas  59.957847  59.354099  68.700436  63.249094  61.117406  63.949402  \
# Ancash    51.832932  54.948729   54.89229  63.157986  69.871893  65.974263
# Apurímac  61.142286  58.399844  53.339032  68.811045  67.231891  66.631860
# Arequipa  80.425588  82.699463  74.576988  89.332278  86.075536  81.631867
# Ayacucho  53.573045  48.976799  49.974511  50.725844  59.555397  50.888510
#
#                2007       2008       2009       2010       2011       2012
# REGION
# Amazonas  53.709937  61.203100  60.972830  61.817111  64.086410  68.889297  \
# Ancash    71.589496  74.242416  68.823060  72.112824  78.050841  77.733436
# Apurímac  67.815028  70.708028  78.780984  78.609518  78.604583  77.389747
# Arequipa  88.978596  90.419176  87.895861  93.502294  86.709338  90.422880
# Ayacucho  64.104548  62.537206  61.884559  62.943788  69.388476  71.504411
#
# ...

# %%
print ('Dimensiones de los datos:', df_tendencia.shape)
# Out:
# Dimensiones de los datos: (26, 16)

# %%
años = list(map(str, range(2001, 2016)))  # note habilitar a un año adicional

años
# Out:
# ['2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015']

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # opcional: para mostrar el estilo ggplot-like 

# chequeando la última versión de Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.7.1

# %%
df_tendencia.sort_values(['REGION'], ascending=True, axis=0, inplace=True)

# obteniendo las 5 primeros años
df_top5 = df_tendencia.head(5)    #pudo tambien ser tail(5) para seleccionar los 5 últimos

# transpose the dataframe
df_top5 = df_top5[años].transpose() 

df_top5.head()
# Out:
# REGION   Amazonas     Ancash   Apurímac   Arequipa   Ayacucho
# 2001    59.957847  51.832932  61.142286  80.425588  53.573045
# 2002    59.354099  54.948729  58.399844  82.699463  48.976799
# 2003    68.700436   54.89229  53.339032  74.576988  49.974511
# 2004    63.249094  63.157986  68.811045  89.332278  50.725844
# 2005    61.117406  69.871893  67.231891  86.075536  59.555397

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='area', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('Tendencia de conclusión, primaria, grupo de edades 12-13 (% del total)')
plt.ylabel('Porcentaje')
plt.xlabel('Años')

plt.show()

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='area', 
             alpha=0.25, # 0-1, default value a= 0.5
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('Tendencia de conclusión, primaria, grupo de edades 12-13 (% del total)')
plt.ylabel('Porcentaje')
plt.xlabel('Años')

plt.show()

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='line', 
             stacked=False,
             figsize=(20, 5), # pass a tuple (x, y) size
             )

plt.title('Tendencia de conclusión, primaria, grupo de edades 12-13 (% del total)')
plt.ylabel('Porcentaje')
plt.xlabel('Años')

plt.show()

# %%
df_top5.index = df_top5.index.map(int) # let's change the index values of df_top5 to type integer for plotting
df_top5.plot(kind='bar', 
             stacked=False,
             figsize=(20, 10), # pass a tuple (x, y) size
             )

plt.title('Tendencia de conclusión, primaria, grupo de edades 12-13 (% del total)')
plt.ylabel('Porcentaje')
plt.xlabel('Años')

plt.show()

# %%
df_tendencia['2013'].head()
# Out:
# REGION
# Amazonas    71.296644
# Ancash      75.246196
# Apurímac    79.448232
# Arequipa    89.820127
# Ayacucho    72.782221
# Name: 2013, dtype: float64

# %%
import numpy as np
# np.histogram returns 2 values
count, bin_edges = np.histogram(df_tendencia['2013'])

print(count) # frequency count
print(bin_edges) # bin ranges, default = 10 bins (10 rangos de agrupamiento)
# Out:
# [2 0 0 5 2 4 2 5 3 3]
# [59.84066679 63.28819655 66.73572631 70.18325607 73.63078583 77.07831559
#  80.52584535 83.97337511 87.42090487 90.86843463 94.31596439]

# %%
df_tendencia['2013'].plot(kind='hist', figsize=(8, 5))

plt.title('Histograma de Departamentos que concluyen primaria en 2013') # add a title to the histogram
plt.ylabel('Número de Departamentos') # add y-label
plt.xlabel('% de Tendencia que concluyeron primaria') # add x-label

plt.show()

# %%
df_tendencia.loc[['Lima Metropolitana', 'Arequipa', 'Piura'], años]
# Out:
#                          2001       2002       2003       2004       2005
# REGION
# Lima Metropolitana  81.765596  80.247977  85.769594  80.860804  82.199969  \
# Arequipa            80.425588  82.699463  74.576988  89.332278  86.075536
# Piura               69.998682  66.784040  67.679314  77.220608  74.714148
#
#                          2006       2007       2008       2009       2010
# REGION
# Lima Metropolitana  82.563505  84.950125  84.261933  86.509562  86.746238  \
# Arequipa            81.631867  88.978596  90.419176  87.895861  93.502294
# Piura               69.987455  77.544082  68.999683  76.207409  78.329764
#
#                          2011       2012       2013       2014       2015
# REGION
# Lima Metropolitana  87.602888  88.552365  87.683754  89.320336  91.006083
# Arequipa            86.709338  90.422880  89.820127  89.085301  92.104252
# Piura               84.031454  78.237481  77.264886  82.076339  76.808891

# %%
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_t = df_tendencia.loc[['Lima Metropolitana', 'Arequipa', 'Piura'], años].transpose()
df_t.head(15)
# Out:
# REGION Lima Metropolitana   Arequipa      Piura
# 2001            81.765596  80.425588  69.998682
# 2002            80.247977  82.699463   66.78404
# 2003            85.769594  74.576988  67.679314
# 2004            80.860804  89.332278  77.220608
# 2005            82.199969  86.075536  74.714148
# 2006            82.563505  81.631867  69.987455
# 2007            84.950125  88.978596  77.544082
# 2008            84.261933  90.419176  68.999683
# 2009            86.509562  87.895861  76.207409
# 2010            86.746238  93.502294  78.329764
# 2011            87.602888  86.709338  84.031454
# 2012            88.552365   90.42288  78.237481
# 2013            87.683754  89.820127  77.264886
# 2014            89.320336  89.085301  82.076339
# 2015            91.006083  92.104252  76.808891

# %%
df_arequipa = df_tendencia.loc['Arequipa', años]
df_arequipa.head()
# Out:
# 2001    80.425588
# 2002    82.699463
# 2003    74.576988
# 2004    89.332278
# 2005    86.075536
# Name: Arequipa, dtype: object

# %%
df_arequipa.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Año') # add to x-label to the plot
plt.ylabel('Tasa de conclusión, primaria, grupo de edades 12-13 (% del total)') # add y-label to the plot
plt.title('Analizando la tendencia de la Región Arequipa desde 2001 hasta 2015') # add title to the plot

plt.show()

# %%
# La suma de las filas: df_tendencia.sum(axis=1)
# df_tendencia.sum(axis=1) / (len(df_tendencia.columns)-1)   ## -1 para restar la columna Region

df_tendencia['Promedio'] =  (len(df_tendencia.columns)-1) 

# sort dataframe on 'Total' column (descending)
df_tendencia.sort_values(by='Promedio', ascending=True, inplace=True)

# get top de todas las regiones
df_top25 = df_tendencia['Promedio'].tail(26)
df_top25
# Out:
# REGION
# Amazonas              15
# Tacna                 15
# San Martín            15
# Puno                  15
# Piura                 15
# Pasco                 15
# Moquegua              15
# Madre de Dios         15
# Loreto                15
# Lima Provincias       15
# Lima Metropolitana    15
# Lambayeque            15
# La Libertad           15
# Junín                 15
# Ica                   15
# Huánuco               15
# Huancavelica          15
# Cusco                 15
# Callao                15
# Cajamarca             15
# Ayacucho              15
# Arequipa              15
# Apurímac              15
# Ancash                15
# Tumbes                15
# Ucayali               15
# Name: Promedio, dtype: int64

# %%
# generando el ploteo
df_top25.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Valor de Tendencia en %')
plt.title('Tasa de conclusión, primaria, grupo de edades 12-13 (% del total) entre 2001 a 2015')

# anota valor de etiqueta para cada país
for index, value in enumerate(df_top25): 
    label = format(int(value), ',') # format int with commas
    
    # coloque el texto al final de la barra 
    plt.annotate(label, xy=(value, index), color='red')

plt.show()

# %%
import numpy as np  # utilizado para múltiples cómputos científicas en Python
import pandas as pd # librería para estructura de datos
import folium       # utilizada para grafica de mapas

# Define el mapa mundial centrado alrededor de Lima, Perú con un zoom bajo
# https://python-graph-gallery.com/288-map-background-with-folium/

world_map = folium.Map(location=[-12.0431800, -77.0282400], zoom_start=6, tiles='Stamen Terrain')
#Geolocalización de las primeras 5 ciudades según última gráfica
#https://www.antipodas.net/coordenadaspais/peru/lima.php 
folium.Marker([-16.3988900, -71.5350000], popup='Arequipa').add_to(world_map) 
folium.Marker([-18.0146500, -70.2536200], popup='Tacna').add_to(world_map)
folium.Marker([-17.1983200, -70.9356700], popup='Moquegua').add_to(world_map)
folium.Marker([-12.0431800, -77.0282400], popup='Lima Metropolitana').add_to(world_map)
folium.Marker([-14.0677700, -75.7286100], popup='Ica').add_to(world_map)
# mostrando el mapa
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
